# %% [markdown]
# <a href="https://colab.research.google.com/github/woo13sd/rupture-theory/blob/main/Rupture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 2. Install Fortran and set up CAMB base environment
# %cd /content

# Install required packages
# !apt-get install -y gfortran

# Download CAMB (official source) and extract it
# !wget https://github.com/cmbant/CAMB/archive/refs/heads/master.zip -O camb.zip
# !unzip camb.zip
# !mv CAMB-master camb
# %cd camb

# Clean and build CAMB using Makefile (you can replace .f90 files before this step if needed)
# !make clean
# !make
# Out:
# /content
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gfortran is already the newest version (4:11.2.0-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# --2025-07-28 23:13:47--  https://github.com/cmbant/CAMB/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/cmbant/CAMB/zip/refs/heads/master [following]
# --2025-07-28 23:13:47--  https://codeload.github.com/cmbant/CAMB/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘camb.zip’
#
# ...
